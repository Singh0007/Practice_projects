# %%
import pandas as pd,numpy as np ,seaborn as sns,matplotlib.pyplot as plt

# %%
df=pd.read_csv("titanic_train.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %% [markdown]
# # EDA

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.corr()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# by summerising above we see that the age ,cabin and embarked columns havig the missing values

# %% [markdown]
# from this we can see that the age and embarked having many null values

# %% [markdown]
# we can see that the missing values in these columns we can only remove the cabin columns because it cant affect out result but we can fill the age column with the mean value

# %% [markdown]
# # Data Integrity Check

# %% [markdown]
# Dataset can contain whitespaces, missing value, duplicates entries, let investigate integrity of data before proceeding for further analysis.

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Checking for presense of whitespaces, '?','null'

# %%
df.isin([' ','?','-','null','NA']).sum().any()
# Out:
# False

# %% [markdown]
# ###  missing value check

# %%
plt.figure(figsize = (8,6))
sns.heatmap(df.isnull())
plt.show()

# %%
missing_values = df.isnull().sum().sort_values(ascending = False)
percentage_missing_values =(missing_values/len(df))*100
print(pd.concat([missing_values, percentage_missing_values], axis =1, keys =['Missing Values', '% Missing data']))
# Out:
#              Missing Values  % Missing data
# Cabin                   687       77.104377
# Age                     177       19.865320
# Embarked                  2        0.224467
# PassengerId               0        0.000000
# Survived                  0        0.000000
# Pclass                    0        0.000000
# Name                      0        0.000000
# Sex                       0        0.000000
# SibSp                     0        0.000000
# Parch                     0        0.000000
# Ticket                    0        0.000000
# Fare                      0        0.000000

# %% [markdown]
# ### Observation :
# Dataset do not contain any duplicate values, whitespaces,"?","-" .
#
# Feature'Age', 'Embarked', and 'Cabin' have null values.
#
# 19.86% of 'Age' data is null value,0.22% of 'Embarked' is null value, while 77.10% 'Cabin' data is null value.
#
# Dropping 'Cabin' since 77.10% of its values is missing and therefore it cannot contribute to building a good model for predicting the target variable values.

# %%
df.describe(include= object)
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %% [markdown]
# these are the object data type

# %%
df.nunique()
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64

# %% [markdown]
# "Survived" - Target / Label column has 2 categories / classes.
#
# "sex" - Feature column has 2 categories / classes.
#
# "Pclass" - Feature column has 2 categories / classes.
#
# "Embarked" - Feature column has 3 categories / classes.
#
# "SibSp" - Feature column has 7 discrete values.
#
# "Parch" - Feature column has 7 discrete values.
#
# Cabin is unnecessary feature with missing value so we can drop column Cabin.

# %%
df.drop('Cabin',axis=1,inplace=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Embarked
# 0        0         A/5 21171   7.2500        S
# 1        0          PC 17599  71.2833        C
# 2        0  STON/O2. 3101282   7.9250        S
# 3        0            113803  53.1000        S
# 4        0            373450   8.0500        S
# ..     ...               ...      ...      ...
# 886      0            211536  13.0000        S
# 887      0            112053  30.0000        S
# 888      2        W./C. 6607  23.4500        S
# 889      0            111369  30.0000        C
# 890      0            370376   7.7500        Q
#
# [891 rows x 11 columns]

# %% [markdown]
# # How Many Survived?

# %%
df['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
plt.rcParams["figure.autolayout"] = True
sns.set_palette('hsv')
f,ax=plt.subplots(1,2,figsize=(14,7))
df['Survived'].value_counts().plot.pie(explode=[0,0.1],textprops ={ 'fontsize':13,'fontweight' :'bold'},
                                       autopct='%2.1f%%', ax=ax[0],shadow=True)
ax[0].set_title('Survival Distribution',fontsize=18,fontweight ='bold')
ax[0].set_ylabel('')
sns.countplot('Survived',data=df,ax=ax[1])
ax[1].set_title('Survival Count',fontsize=18,fontweight ='bold')
ax[1].set_xlabel("Survival Category",fontsize=18,fontweight ='bold')
ax[1].set_ylabel("Survival Count", fontsize= 18, fontweight='bold')
plt.xticks(fontsize=18,fontweight ='bold')
plt.show()
# Out:
# C:\Users\GauRav SingH\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# Out of 891 passengers in vessel, only around 342 survived i.e only 38.4% of the passenger survived the crash.

# %% [markdown]
# # Let Investiage Gender-wise Survival Rate of Passengers

# %%
df.groupby(['Sex','Survived'])['Survived'].count()
# Out:
# Sex     Survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# Name: Survived, dtype: int64

# %%
plt.rcParams["figure.autolayout"] = True
sns.set_palette('gnuplot_r')
f,ax=plt.subplots(1,2,figsize=(15,7))
df[['Sex','Survived']].groupby(['Sex']).mean().plot.bar(ax=ax[0])
plt.xticks(fontsize=18,fontweight ='bold',rotation=0)
ax[0].set_title('Gender Wise Mean Survival Rate',fontsize=20,fontweight ='bold')

ax[0].set_xlabel("Gender",fontsize=18,fontweight ='bold')
ax[0].set_ylabel("Mean Survival Rate", fontsize= 18, fontweight='bold')
sns.countplot('Sex', hue='Survived', data=df,ax=ax[1])
ax[1].set_title('Gender-wise Survival Rate of Passengers ',fontsize=20,fontweight ='bold')
plt.xticks(fontsize=18,fontweight ='bold')
ax[1].set_xlabel("Gender",fontsize=18,fontweight ='bold')
ax[1].set_ylabel("Survival Count", fontsize= 18, fontweight='bold')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\GauRav SingH\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# The number of men on the ship is lot more than the number of women.
#
# Still the number of women saved is almost twice the number of males saved.* *The survival rates for a Woman on ship is around 75% while that for men in around 18-19%.*

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %%
pd.crosstab(df.Pclass,df.Survived,margins=True).style.background_gradient()
# Out:
# <style type="text/css">
# #T_00130_row0_col0, #T_00130_row1_col1, #T_00130_row1_col2 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_00130_row0_col1 {
#   background-color: #dddbec;
#   color: #000000;
# }
# #T_00130_row0_col2 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_00130_row1_col0 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_00130_row2_col0 {
#   background-color: #3790c0;
#   color: #f1f1f1;
# }
# #T_00130_row2_col1 {
#   background-color: #ece7f2;
#   color: #000000;
# }
# #T_00130_row2_col2 {
#   background-color: #8eb3d5;
#   color: #000000;
# }
# #T_00130_row3_col0, #T_00130_row3_col1, #T_00130_row3_col2 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_00130">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Survived</th>
#       <th id="T_00130_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_00130_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_00130_level0_col2" class="col_heading level0 col2" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Pclass</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_00130_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_00130_row0_col0" class="data row0 col0" >80</td>
#       <td id="T_00130_row0_col1" class="data row0 col1" >136</td>
#       <td id="T_00130_row0_col2" class="data row0 col2" >216</td>
#     </tr>
#     <tr>
#       <th id="T_00130_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_00130_row1_col0" class="data row1 col0" >97</td>
#       <td id="T_00130_row1_col1" class="data row1 col1" >87</td>
#       <td id="T_00130_row1_col2" class="data row1 col2" >184</td>
#     </tr>
#     <tr>
#       <th id="T_00130_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_00130_row2_col0" class="data row2 col0" >372</td>
#       <td id="T_00130_row2_col1" class="data row2 col1" >119</td>
#       <td id="T_00130_row2_col2" class="data row2 col2" >491</td>
#     </tr>
#     <tr>
#       <th id="T_00130_level0_row3" class="row_heading level0 row3" >All</th>
#       <td id="T_00130_row3_col0" class="data row3 col0" >549</td>
#       <td id="T_00130_row3_col1" class="data row3 col1" >342</td>
#       <td id="T_00130_row3_col2" class="data row3 col2" >891</td>
#     </tr>
#   </tbody>
# </table>

# %%
plt.rcParams["figure.autolayout"] = True
sns.set_palette('rainbow_r')
f,ax=plt.subplots(1,2,figsize=(15,7))
df['Pclass'].value_counts().plot.bar(ax=ax[0])
ax[0].set_title('Number of Passengers By Pclass', fontsize= 20, fontweight='bold')
ax[0].set_ylabel('Passengers Count',fontsize= 18, fontweight='bold')
ax[0].set_xlabel('Passengers Class', fontsize= 18, fontweight='bold')
sns.countplot('Pclass',hue='Survived', data=df,ax=ax[1])
ax[1].set_title('Pclass:Survived Vs Dead', fontsize= 20, fontweight='bold')
ax[1].set_ylabel('Passengers Count',fontsize= 18, fontweight='bold')
ax[1].set_xlabel('Passengers Class', fontsize= 18, fontweight='bold')
plt.show()
# Out:
# C:\Users\GauRav SingH\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# We can clearly, see that Passengers of Pclass 1 were given a very high priority while rescue. Even though the the number of passengers in Pclass 3 were a lot higher, still the number of survival from Pclass 3 is very low, somewhere around 25%.*
#
# For Pclass 1 % Survived is around 63% while for pclass2 is around 48%. In Conclusion money and status matters. Such a materialistic world.

# %% [markdown]
# ### Lets Dive in little bit more and check for other interesting observations. Lets check survival rate with Sex and Pclass Together.

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %%
pd.crosstab([df.Sex,df.Survived],df.Pclass,margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_df121_row0_col0, #T_df121_row0_col1, #T_df121_row0_col3, #T_df121_row3_col2 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_df121_row0_col2, #T_df121_row1_col2 {
#   background-color: #f1f866;
#   color: #000000;
# }
# #T_df121_row1_col0 {
#   background-color: #96cb66;
#   color: #000000;
# }
# #T_df121_row1_col1 {
#   background-color: #a3d166;
#   color: #000000;
# }
# #T_df121_row1_col3 {
#   background-color: #cfe766;
#   color: #000000;
# }
# #T_df121_row2_col0 {
#   background-color: #a7d366;
#   color: #000000;
# }
# #T_df121_row2_col1, #T_df121_row2_col3 {
#   background-color: #85c266;
#   color: #000000;
# }
# #T_df121_row2_col2 {
#   background-color: #6eb666;
#   color: #f1f1f1;
# }
# #T_df121_row3_col0 {
#   background-color: #cde666;
#   color: #000000;
# }
# #T_df121_row3_col1 {
#   background-color: #f0f866;
#   color: #000000;
# }
# #T_df121_row3_col3 {
#   background-color: #f7fb66;
#   color: #000000;
# }
# #T_df121_row4_col0, #T_df121_row4_col1, #T_df121_row4_col2, #T_df121_row4_col3 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_df121">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >Pclass</th>
#       <th id="T_df121_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_df121_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_df121_level0_col2" class="col_heading level0 col2" >3</th>
#       <th id="T_df121_level0_col3" class="col_heading level0 col3" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Sex</th>
#       <th class="index_name level1" >Survived</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_df121_level0_row0" class="row_heading level0 row0" rowspan="2">female</th>
#       <th id="T_df121_level1_row0" class="row_heading level1 row0" >0</th>
#       <td id="T_df121_row0_col0" class="data row0 col0" >3</td>
#       <td id="T_df121_row0_col1" class="data row0 col1" >6</td>
#       <td id="T_df121_row0_col2" class="data row0 col2" >72</td>
#       <td id="T_df121_row0_col3" class="data row0 col3" >81</td>
#     </tr>
#     <tr>
#       <th id="T_df121_level1_row1" class="row_heading level1 row1" >1</th>
#       <td id="T_df121_row1_col0" class="data row1 col0" >91</td>
#       <td id="T_df121_row1_col1" class="data row1 col1" >70</td>
#       <td id="T_df121_row1_col2" class="data row1 col2" >72</td>
#       <td id="T_df121_row1_col3" class="data row1 col3" >233</td>
#     </tr>
#     <tr>
#       <th id="T_df121_level0_row2" class="row_heading level0 row2" rowspan="2">male</th>
#       <th id="T_df121_level1_row2" class="row_heading level1 row2" >0</th>
#       <td id="T_df121_row2_col0" class="data row2 col0" >77</td>
#       <td id="T_df121_row2_col1" class="data row2 col1" >91</td>
#       <td id="T_df121_row2_col2" class="data row2 col2" >300</td>
#       <td id="T_df121_row2_col3" class="data row2 col3" >468</td>
#     </tr>
#     <tr>
#       <th id="T_df121_level1_row3" class="row_heading level1 row3" >1</th>
#       <td id="T_df121_row3_col0" class="data row3 col0" >45</td>
#       <td id="T_df121_row3_col1" class="data row3 col1" >17</td>
#       <td id="T_df121_row3_col2" class="data row3 col2" >47</td>
#       <td id="T_df121_row3_col3" class="data row3 col3" >109</td>
#     </tr>
#     <tr>
#       <th id="T_df121_level0_row4" class="row_heading level0 row4" >All</th>
#       <th id="T_df121_level1_row4" class="row_heading level1 row4" ></th>
#       <td id="T_df121_row4_col0" class="data row4 col0" >216</td>
#       <td id="T_df121_row4_col1" class="data row4 col1" >184</td>
#       <td id="T_df121_row4_col2" class="data row4 col2" >491</td>
#       <td id="T_df121_row4_col3" class="data row4 col3" >891</td>
#     </tr>
#   </tbody>
# </table>

# %%
sns.factorplot('Pclass','Survived',hue='Sex',data=df)
# Out:
# C:\Users\GauRav SingH\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\GauRav SingH\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# Observation :-
# Looking at the CrossTab and the Factorplot, we can easily infer that survival for Women from Pclass 1 is about 95-96%, as only 3 out of 94 Women from Pclass1 died.

# %% [markdown]
# # Age

# %%
print('Oldest Passenger was of:',df['Age'].max(),'Years')
print('Youngest Passenger was of:',df['Age'].min(),'Years')
print('Average Age on th ship :',df['Age'].mean(),'Years')
# Out:
# Oldest Passenger was of: 80.0 Years
# Youngest Passenger was of: 0.42 Years
# Average Age on th ship : 29.69911764705882 Years

# %%
f,ax=plt.subplots(1,2,figsize=(15,7))
sns.violinplot('Pclass','Age',hue='Survived',data=df, split=True, ax=ax[0])
ax[0].set_title("Pclass wise distribution of age and Survived",fontsize=20)
ax[0].set_yticks(range(0,110,10))
ax[0].set_ylabel('Passengers Age',fontsize= 18, fontweight='bold')
ax[0].set_xlabel('Passengers Class', fontsize= 18, fontweight='bold')
sns.violinplot('Sex','Age',hue='Survived',data=df,split=True,ax=ax[1])
ax[1].set_title("gernder-wise Age vs Survived",fontsize=20)
sns.violinplot('Sex','Age', hue='Survived',data=df, split= True, ax=ax[1])
ax[1].set_title('Gender-Wise Age Vs Survived',fontsize= 20, fontweight='bold')
ax[1].set_yticks(range(0,110,10))
ax[1].set_ylabel('Passengers Age',fontsize= 18, fontweight='bold')
ax[1].set_xlabel('Gender', fontsize= 18, fontweight='bold')
plt.show()
# Out:
# C:\Users\GauRav SingH\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\GauRav SingH\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\GauRav SingH\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# Observation :-
#
# The number of children increases with Pclass and the survival ratee for passenengers below age 10 looks to be good irrespective of the Pclass.
#
# Survival chances for Passenegers aged 20-50 from Pclass 1 is high and even better for women.
#
# For males, the survival chances decreases with increase in age.

# %% [markdown]
# # handling missing values with age columns

# %% [markdown]
# *Looking Upon the name Name Feature, we can see that the names have as salutation like Mr or Mrs. Thus we can assign the mean values of Mr, Mrs etc. to the respective groups.*

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %%
df['sirname']=0
for i in df:
    df['sirname']=df.Name.str.extract("([A-Za-z]+)\.") # Extract the Salutations with Regex

# %%
pd.crosstab(df.sirname,df.Sex).T
# Out:
# sirname  Capt  Col  Countess  Don  Dr  Jonkheer  Lady  Major  Master  Miss  \
# Sex
# female      0    0         1    0   1         0     1      0       0   182
# male        1    2         0    1   6         1     0      2      40     0
#
# sirname  Mlle  Mme   Mr  Mrs  Ms  Rev  Sir
# Sex
# female      2    1    0  125   1    0    0
# male        0    0  517    0   0    6    1

# %% [markdown]
# as we see there is 17 diffrent sirnames we can replace these diffrent sirname to noraml like miss ,mrs etc

# %%
df['sirname'].replace(['Mlle','Mme','Ms','Dr','Major','Lady','Countess','Jonkheer','Col','Rev','Capt','Sir','Don'],
                      ['Miss','Miss','Miss','Mr','Mr','Mrs','Mrs','Other','Other','Other','Mr','Mr','Mr'],inplace=True)

# %%
df.groupby('sirname')['Age'].mean()
# Out:
# sirname
# Master     4.574167
# Miss      21.860000
# Mr        32.739609
# Mrs       35.981818
# Other     45.888889
# Name: Age, dtype: float64

# %% [markdown]
# ### Now we can fill nan values according to the sirnames

# %%
df.loc[(df.Age.isnull() & (df.sirname)=='Mr'), 'Age'].fillna(32.73,inplace = True)

# %%
df.loc[((df.Age.isnull())&(df.sirname)=='Mr'), 'Age']=32.73
df.loc[(df.Age.isnull() & (df.sirname)=='Mrs'),'Age']==35.98
df.loc[((df.Age.isnull())&(df.sirname)=='Master'), 'Age']=4.57
df.loc[((df.Age.isnull())&(df.sirname)=='Miss'), 'Age']=21.86
df.loc[((df.Age.isnull())&(df.sirname)=='Other'), 'Age']=45.889

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         2
# sirname          0
# dtype: int64

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
df[df['Survived']==0].Age.plot.hist(ax=ax[0],bins=20,edgecolor='black',color='red')
ax[0].set_title('Survived = 0',fontsize= 20, fontweight='bold')
x1=list(range(0,85,5))
ax[0].set_xticks(x1)
df[df['Survived']==1].Age.plot.hist(ax=ax[1],bins=20,edgecolor='black',color='green')
ax[1].set_title('Survived=1',fontsize= 20, fontweight='bold')
x2=list(range(0,85,5))
ax[1].set_xticks(x2)
plt.show()

# %%
sns.factorplot('Pclass','Survived',col='sirname',data=df)
# Out:
# C:\Users\GauRav SingH\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\GauRav SingH\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# The women and child first policy thus holds true irrespective of the class.

# %% [markdown]
# # Analysis Embarked vs Survival

# %%
pd.crosstab([df.Embarked,df.Pclass],[df.Sex,df.Survived],margins=True)
# Out:
# Sex             female      male       All
# Survived             0    1    0    1
# Embarked Pclass
# C        1           1   42   25   17   85
#          2           0    7    8    2   17
#          3           8   15   33   10   66
# Q        1           0    1    1    0    2
#          2           0    2    1    0    3
#          3           9   24   36    3   72
# S        1           2   46   51   28  127
#          2           6   61   82   15  164
#          3          55   33  231   34  353
# All                 81  231  468  109  889

# %%
sns.factorplot('Embarked','Survived',data=df)
fig=plt.gcf()
fig.set_size_inches(6,4)
plt.show()
# Out:
# C:\Users\GauRav SingH\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\GauRav SingH\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
f,ax=plt.subplots(2,2,figsize=(20,18))
sns.countplot('Embarked',data=df,ax=ax[0,0])
ax[0,0].set_title('No of Passengers Boarded',fontsize= 20, fontweight='bold')
ax[0,0].set_ylabel('Passengers Count',fontsize= 18, fontweight='bold')
ax[0,0].set_xlabel('Embarked', fontsize= 18, fontweight='bold')

sns.countplot('Embarked',hue='Sex',data=df,ax=ax[0,1])
ax[0,1].set_title('Male -Female Split for Embarked',fontsize= 20, fontweight='bold')
ax[0,1].set_ylabel('Passengers Count',fontsize= 18, fontweight='bold')
ax[0,1].set_xlabel('Embarked', fontsize= 18, fontweight='bold')

sns.countplot('Embarked',hue="Survived" ,data=df,ax=ax[1,0])
ax[1,0].set_title('Embarked vs Survived',fontsize= 20, fontweight='bold')
ax[1,0].set_ylabel('Passengers Count',fontsize= 18, fontweight='bold')
ax[1,0].set_xlabel('Embarked', fontsize= 18, fontweight='bold')

sns.countplot('Embarked',hue='Pclass',data=df,ax=ax[1,1])
ax[1,1].set_title('Embarked vs Pclass',fontsize= 20, fontweight='bold')
ax[1,1].set_ylabel('Passengers Count',fontsize= 18, fontweight='bold')
ax[1,1].set_xlabel('Embarked', fontsize= 18, fontweight='bold')
plt.subplots_adjust(wspace=0.2,hspace=0.5)
plt.show()
# Out:
# C:\Users\GauRav SingH\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\GauRav SingH\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\GauRav SingH\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\GauRav SingH\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# Observation :-
# Maximum passengers boarded from S. Majority of them being from Pclass 3.
#
# The Passengers from C look to be lucky as as good proportion of them survived. The reason for this may be the rescue of all the Pclass 1 and Pclass 2 Passengers.
#
# The Embark S looks to the port from where majority of the rich people. Still the chances for survival is low here, that is because many passengers from Pclass 3 around 81% didn't survive.
#
# Port Q had almost 95% of the passengers were from Pclass 3.

# %%
sns.factorplot('Pclass','Survived', hue='Sex', col='Embarked',data=df)
plt.show()
# Out:
# C:\Users\GauRav SingH\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\GauRav SingH\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# Observation :-
# The survival chances are almost 1 for women for Pclass 1 and Pclass 2 irrespective of the Pclass.
#
# Port S looks to be very unlucky for Pclass 3 passengers as the survival rate for both men and women is very low.
#
# Port Q looks to be unluckiest for Men, as almost all were from Pclass 3.

# %%
df.Embarked.isnull().any()
# Out:
# True

# %%
df['Embarked'].fillna('S', inplace=True)

# %%
df.Embarked.isnull().any()
# Out:
# False

# %% [markdown]
# # SibSip vs Survived

# %%
pd.crosstab([df.SibSp],[df.Survived],margins=True)
# Out:
# Survived    0    1  All
# SibSp
# 0         398  210  608
# 1          97  112  209
# 2          15   13   28
# 3          12    4   16
# 4          15    3   18
# 5           5    0    5
# 8           7    0    7
# All       549  342  891

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
sns.barplot('SibSp','Survived',data=df,ax=ax[0])
ax[0].set_title('SibSp Vs Survived',fontsize= 20, fontweight='bold')

sns.factorplot('SibSp','Survived',data=df, ax=ax[1])
ax[1].set_title('SibSp Vs Survived',fontsize= 20, fontweight='bold')
ax[1].set_ylabel('SibSp',fontsize= 18, fontweight='bold')
ax[1].set_xlabel('Survived', fontsize= 18, fontweight='bold')
plt.tight_layout()
#plt.subplots_adjust(wspace=0.2,hspace=0.5)
plt.show()
# Out:
# C:\Users\GauRav SingH\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\GauRav SingH\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\GauRav SingH\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\GauRav SingH\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:3775: UserWarning: catplot is a figure-level function and does not accept target axes. You may wish to try pointplot
#   warnings.warn(msg, UserWarning)

# %%
pd.crosstab([df.SibSp],[df.Pclass],margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_8c093_row0_col0 {
#   background-color: #5dae66;
#   color: #f1f1f1;
# }
# #T_8c093_row0_col1 {
#   background-color: #59ac66;
#   color: #f1f1f1;
# }
# #T_8c093_row0_col2 {
#   background-color: #49a466;
#   color: #f1f1f1;
# }
# #T_8c093_row0_col3 {
#   background-color: #51a866;
#   color: #f1f1f1;
# }
# #T_8c093_row1_col0 {
#   background-color: #abd566;
#   color: #000000;
# }
# #T_8c093_row1_col1 {
#   background-color: #b3d966;
#   color: #000000;
# }
# #T_8c093_row1_col2 {
#   background-color: #d6eb66;
#   color: #000000;
# }
# #T_8c093_row1_col3 {
#   background-color: #c5e266;
#   color: #000000;
# }
# #T_8c093_row2_col0, #T_8c093_row2_col2 {
#   background-color: #fafc66;
#   color: #000000;
# }
# #T_8c093_row2_col1 {
#   background-color: #f4fa66;
#   color: #000000;
# }
# #T_8c093_row2_col3, #T_8c093_row4_col2 {
#   background-color: #f9fc66;
#   color: #000000;
# }
# #T_8c093_row3_col0, #T_8c093_row3_col2, #T_8c093_row3_col3, #T_8c093_row4_col3 {
#   background-color: #fcfe66;
#   color: #000000;
# }
# #T_8c093_row3_col1, #T_8c093_row6_col2 {
#   background-color: #fefe66;
#   color: #000000;
# }
# #T_8c093_row4_col0, #T_8c093_row4_col1, #T_8c093_row5_col0, #T_8c093_row5_col1, #T_8c093_row5_col2, #T_8c093_row5_col3, #T_8c093_row6_col0, #T_8c093_row6_col1, #T_8c093_row6_col3 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_8c093_row7_col0, #T_8c093_row7_col1, #T_8c093_row7_col2, #T_8c093_row7_col3 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_8c093">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Pclass</th>
#       <th id="T_8c093_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_8c093_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_8c093_level0_col2" class="col_heading level0 col2" >3</th>
#       <th id="T_8c093_level0_col3" class="col_heading level0 col3" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >SibSp</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8c093_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8c093_row0_col0" class="data row0 col0" >137</td>
#       <td id="T_8c093_row0_col1" class="data row0 col1" >120</td>
#       <td id="T_8c093_row0_col2" class="data row0 col2" >351</td>
#       <td id="T_8c093_row0_col3" class="data row0 col3" >608</td>
#     </tr>
#     <tr>
#       <th id="T_8c093_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8c093_row1_col0" class="data row1 col0" >71</td>
#       <td id="T_8c093_row1_col1" class="data row1 col1" >55</td>
#       <td id="T_8c093_row1_col2" class="data row1 col2" >83</td>
#       <td id="T_8c093_row1_col3" class="data row1 col3" >209</td>
#     </tr>
#     <tr>
#       <th id="T_8c093_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8c093_row2_col0" class="data row2 col0" >5</td>
#       <td id="T_8c093_row2_col1" class="data row2 col1" >8</td>
#       <td id="T_8c093_row2_col2" class="data row2 col2" >15</td>
#       <td id="T_8c093_row2_col3" class="data row2 col3" >28</td>
#     </tr>
#     <tr>
#       <th id="T_8c093_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8c093_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_8c093_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_8c093_row3_col2" class="data row3 col2" >12</td>
#       <td id="T_8c093_row3_col3" class="data row3 col3" >16</td>
#     </tr>
#     <tr>
#       <th id="T_8c093_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_8c093_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_8c093_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_8c093_row4_col2" class="data row4 col2" >18</td>
#       <td id="T_8c093_row4_col3" class="data row4 col3" >18</td>
#     </tr>
#     <tr>
#       <th id="T_8c093_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_8c093_row5_col0" class="data row5 col0" >0</td>
#       <td id="T_8c093_row5_col1" class="data row5 col1" >0</td>
#       <td id="T_8c093_row5_col2" class="data row5 col2" >5</td>
#       <td id="T_8c093_row5_col3" class="data row5 col3" >5</td>
#     </tr>
#     <tr>
#       <th id="T_8c093_level0_row6" class="row_heading level0 row6" >8</th>
#       <td id="T_8c093_row6_col0" class="data row6 col0" >0</td>
#       <td id="T_8c093_row6_col1" class="data row6 col1" >0</td>
#       <td id="T_8c093_row6_col2" class="data row6 col2" >7</td>
#       <td id="T_8c093_row6_col3" class="data row6 col3" >7</td>
#     </tr>
#     <tr>
#       <th id="T_8c093_level0_row7" class="row_heading level0 row7" >All</th>
#       <td id="T_8c093_row7_col0" class="data row7 col0" >216</td>
#       <td id="T_8c093_row7_col1" class="data row7 col1" >184</td>
#       <td id="T_8c093_row7_col2" class="data row7 col2" >491</td>
#       <td id="T_8c093_row7_col3" class="data row7 col3" >891</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Observation :-
# The barplot and factor plot show that if as passenger is alone onboard with no siblings, Passenger have 34.5% survival rate. The graph roughly decreases if the number of sibilings increase.
#
# *Surprisingly the survival for families with 5-8 members is 0% . The reason may be Pclass ?*
#
# The crosstab shows that person with SibSp>3 were all in Pclass. It is imminent that all the large families in Pclass 3 (>3) died.

# %% [markdown]
# # Parch Vs Survial

# %%
pd.crosstab([df.Parch],[df.Survived],margins=True)
# Out:
# Survived    0    1  All
# Parch
# 0         445  233  678
# 1          53   65  118
# 2          40   40   80
# 3           2    3    5
# 4           4    0    4
# 5           4    1    5
# 6           1    0    1
# All       549  342  891

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
sns.barplot('Parch','Survived',data=df,ax=ax[0])
ax[0].set_title("parch vs Survived",fontsize=18)
ax[0].set_xlabel("Survived",fontsize=18)
ax[0].set_ylabel('Parch',fontsize=18)

sns.factorplot('Parch','Survived',data=df, ax=ax[1])
ax[1].set_title('Parch Vs Survived',fontsize= 20, fontweight='bold')
ax[1].set_ylabel('Survived',fontsize= 18, fontweight='bold')
ax[1].set_xlabel('Parch', fontsize= 18, fontweight='bold')

plt.subplots_adjust(wspace=0.2,hspace=0.5)
plt.show()
# Out:
# C:\Users\GauRav SingH\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\GauRav SingH\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\GauRav SingH\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\GauRav SingH\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:3775: UserWarning: catplot is a figure-level function and does not accept target axes. You may wish to try pointplot
#   warnings.warn(msg, UserWarning)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked sirname
# 0      0         A/5 21171   7.2500        S      Mr
# 1      0          PC 17599  71.2833        C     Mrs
# 2      0  STON/O2. 3101282   7.9250        S    Miss
# 3      0            113803  53.1000        S     Mrs
# 4      0            373450   8.0500        S      Mr

# %% [markdown]
# # Fare vs Survived

# %%
pd.crosstab([df.Fare],[df.Survived],margins=True)
# Out:
# Survived    0    1  All
# Fare
# 0.0        14    1   15
# 4.0125      1    0    1
# 5.0         1    0    1
# 6.2375      1    0    1
# 6.4375      1    0    1
# ...       ...  ...  ...
# 247.5208    1    1    2
# 262.375     0    2    2
# 263.0       2    2    4
# 512.3292    0    3    3
# All       549  342  891
#
# [249 rows x 3 columns]

# %%
print("Highest Fare",df['Fare'].max())
print("Highest Fare",df['Fare'].min())
print("Highest Fare",df['Fare'].mean())
# Out:
# Highest Fare 512.3292
# Highest Fare 0.0
# Highest Fare 32.204207968574636

# %%
f,ax=plt.subplots(1,3,figsize=(20,7))
sns.distplot(df[df['Pclass']==1].Fare,ax=ax[0])
ax[0].set_title("fares in pclass 1",fontsize=20 )
ax[0].set_xlabel("Density",fontsize=15)
ax[0].set_ylabel('Fare',fontsize=15)


sns.distplot(df[df['Pclass']==2].Fare,ax=ax[1])
ax[1].set_title("fares in pclass 2",fontsize=20 )
ax[1].set_xlabel("Density",fontsize=15)
ax[1].set_ylabel('Fare',fontsize=15)

sns.distplot(df[df['Pclass']==3].Fare,ax=ax[2])
ax[2].set_title("fares in pclass 1",fontsize=20 )
ax[2].set_xlabel("Density",fontsize=15)
ax[2].set_ylabel('Fare',fontsize=15)
# Out:
# C:\Users\GauRav SingH\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\GauRav SingH\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\GauRav SingH\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0, 0.5, 'Fare')

# %% [markdown]
# There looks to be a large distribution in the fares of Passengers in Pclass1 and this distribution goes on decreasing as the standards reduces. As this is also Continous , we can convert into discrete values by using binning

# %%
sns.pairplot(data=df, hue='Pclass')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# now check the co relation

# %%
df.corr()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
plt.figure(figsize=(9,6))
sns.heatmap(df.corr(),annot=True,cmap='magma',linewidth=0.8)
# Out:
# <AxesSubplot:>

# %% [markdown]
# co relation with target variable survived

# %%
plt.figure(figsize=(12,4))
df.corr()['Survived'].drop(['Survived']).plot(kind='bar',color='g')
plt.xlabel("features",fontsize=15)
plt.ylabel("survived",fontsize=15)
plt.show()

# %% [markdown]
# # outliers detection

# %%
# find out the columns with their respected data types

df.columns.to_series().groupby(df.dtypes).groups
# Out:
# {int64: ['PassengerId', 'Survived', 'Pclass', 'SibSp', 'Parch'], float64: ['Age', 'Fare'], object: ['Name', 'Sex', 'Ticket', 'Embarked', 'sirname']}

# %%
# Droping unnecessary column for further investigation
df.drop(["PassengerId", "Name" , "Ticket" ],axis=1,inplace=True)

# %%
df.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked sirname
# 0         0       3    male  22.0      1      0   7.2500        S      Mr
# 1         1       1  female  38.0      1      0  71.2833        C     Mrs
# 2         1       3  female  26.0      0      0   7.9250        S    Miss
# 3         1       1  female  35.0      1      0  53.1000        S     Mrs
# 4         0       3    male  35.0      0      0   8.0500        S      Mr

# %%
# As we have lot of Columns Lets sort Columns by their datatype
df.columns.to_series().groupby(df.dtypes).groups
# Out:
# {int64: ['Survived', 'Pclass', 'SibSp', 'Parch'], float64: ['Age', 'Fare'], object: ['Sex', 'Embarked', 'sirname']}

# %%
Numerical_features= ['Survived', 'Pclass', 'SibSp', 'Parch','Age', 'Fare']
Categorical_features = ['Sex', 'Embarked', 'sirname']

# %%
# Identifying the outliers using boxplot in train dataset
plt.figure(figsize=(10,9),facecolor='white')
plotnumber=1
for i in Numerical_features:
    if plotnumber<=10:
        ax=plt.subplot(3,3,plotnumber)
        sns.boxplot(df[i],color='blue')
        plt.xlabel(i,fontsize=20)
    plotnumber+=1
plt.tight_layout()
# Out:
# C:\Users\GauRav SingH\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\GauRav SingH\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\GauRav SingH\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\GauRav SingH\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\GauRav SingH\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\GauRav SingH\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.distplot(df['Age'])
# Out:
# C:\Users\GauRav SingH\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
# Outlier detection 

def detect_outliers(df,n,features):
    """
    Takes a dataframe df of features and returns a list of the indices
    corresponding to the observations containing more than n outliers according
    to the Tukey method.
    """
    outlier_indices = []
    
    # iterate over features(columns)
    for col in features:
        # 1st quartile (25%)
        Q1 = np.percentile(df[col], 25)
        # 3rd quartile (75%)
        Q3 = np.percentile(df[col],75)
        # Interquartile range (IQR)
        IQR = Q3 - Q1
        
        # outlier step
        outlier_step = 1.5 * IQR
        
        # Determine a list of indices of outliers for feature col
        outlier_list_col = df[(df[col] < Q1 - outlier_step) | (df[col] > Q3 + outlier_step )].index
        
        # append the found outlier indices for col to the list of outlier indices 
        outlier_indices.extend(outlier_list_col)
        
    # select observations containing more than 2 outliers
    outlier_indices = Counter(outlier_indices)        
    multiple_outliers = list( k for k, v in outlier_indices.items() if v > n )
    
    return multiple_outliers

# %%
df.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked sirname
# 0         0       3    male  22.0      1      0   7.2500        S      Mr
# 1         1       1  female  38.0      1      0  71.2833        C     Mrs
# 2         1       3  female  26.0      0      0   7.9250        S    Miss
# 3         1       1  female  35.0      1      0  53.1000        S     Mrs
# 4         0       3    male  35.0      0      0   8.0500        S      Mr

# %%
# detect outliers from Age, SibSp , Parch and Fare
from collections import Counter
Outliers_to_drop = detect_outliers(df,2,["Age","SibSp","Parch","Fare"])

# %%
Outliers_to_drop
# Out:
# [27, 88, 159, 180, 201, 324, 341, 792, 846, 863]

# %%
# Drop outliers
df = df.drop(Outliers_to_drop, axis = 0).reset_index(drop=True)

# %%
df.shape
# Out:
# (881, 9)

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
# Filling missing value of Age 

## Fill Age with the median age of similar rows according to Pclass, Parch and SibSp
# Index of NaN age rows
index_NaN_age = list(df["Age"][df["Age"].isnull()].index)

for i in index_NaN_age :
    age_med = df["Age"].median()
    age_pred = df["Age"][((df['SibSp'] == df.iloc[i]["SibSp"]) & (df['Parch'] == df.iloc[i]["Parch"]) & (df['Pclass'] == df.iloc[i]["Pclass"]))].median()
    if not np.isnan(age_pred) :
        df['Age'].iloc[i] = age_pred
    else :
        df['Age'].iloc[i] = age_med
# Out:
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred
# C:\Users\GauRav SingH\AppData\Local\Temp\ipykernel_2712\2430526638.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[i] = age_pred

# %%
df.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    0
# sirname     0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Encoding Categorical Features

# %%
# Using Label encoder for transforming Categorical data
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for i in Categorical_features:
    df[i] = le.fit_transform(df[i])
df.head()
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked  sirname
# 0         0       3    1  22.0      1      0   7.2500         2        2
# 1         1       1    0  38.0      1      0  71.2833         0        3
# 2         1       3    0  26.0      0      0   7.9250         2        1
# 3         1       1    0  35.0      1      0  53.1000         2        3
# 4         0       3    1  35.0      0      0   8.0500         2        2

# %% [markdown]
# # Standard Scaler

# %%
# Splitting data in target and dependent feature
X = df.drop(['Survived'], axis =1)
Y = df['Survived']

# %%
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()
X_scale = scaler.fit_transform(X)

# %% [markdown]
# ## Machine Learning Model Building

# %%
#Importing Machine learning Model library
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, random_state=67, test_size=.25)
print('Training feature matrix size:',X_train.shape)
print('Training target vector size:',Y_train.shape)
print('Test feature matrix size:',X_test.shape)
print('Test target vector size:',Y_test.shape)
# Out:
# Training feature matrix size: (660, 8)
# Training target vector size: (660,)
# Test feature matrix size: (221, 8)
# Test target vector size: (221,)

# %% [markdown]
# ## Finding best Random state

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix,classification_report,f1_score
maxAccu=0
maxRS=0
for i in range(50,300):
    X_train,X_test,Y_train,Y_test = train_test_split(X_scale,Y,test_size = 0.3, random_state=i)
    log_reg=LogisticRegression()
    log_reg.fit(X_train,Y_train)
    y_pred=log_reg.predict(X_test)
    acc=accuracy_score(Y_test,y_pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print('Best accuracy is', maxAccu ,'on Random_state', maxRS)
# Out:
# Best accuracy is 0.8566037735849057 on Random_state 69

# %% [markdown]
# ## Logistics Regression

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X_scale, Y, random_state=69, test_size=.25)
log_reg=LogisticRegression()
log_reg.fit(X_train,Y_train)
y_pred=log_reg.predict(X_test)
print('\033[1m'+'Logistics Regression Evaluation'+'\033[0m')
print('\n')
print('\033[1m'+'Accuracy Score of Logistics Regression :'+'\033[0m', accuracy_score(Y_test, y_pred))
print('\n')
print('\033[1m'+'Confusion matrix of Logistics Regression :'+'\033[0m \n',confusion_matrix(Y_test, y_pred))
print('\n')
print('\033[1m'+'classification Report of Logistics Regression'+'\033[0m \n',classification_report(Y_test, y_pred))
# Out:
# Logistics Regression Evaluation
#
#
# Accuracy Score of Logistics Regression : 0.8687782805429864
#
#
# Confusion matrix of Logistics Regression :
#  [[120   9]
#  [ 20  72]]
#
#
# classification Report of Logistics Regression
#                precision    recall  f1-score   support
#
#            0       0.86      0.93      0.89       129
#            1       0.89      0.78      0.83        92
#
#     accuracy                           0.87       221
#    macro avg       0.87      0.86      0.86       221
# weighted avg       0.87      0.87      0.87       221

# %%
from sklearn.model_selection import cross_val_score
CVscore = cross_val_score(log_reg, X_scale, Y, cv =5)
print('\033[1m'+'Cross Validation Score', log_reg, ':'+'\033[0m\n')
print("CVScore :" ,CVscore)
print("Mean CV Score :",CVscore.mean())
print("Std deviation :",CVscore.std())
# Out:
# Cross Validation Score LogisticRegression() :
#
# CVScore : [0.77966102 0.79545455 0.77272727 0.78977273 0.82386364]
# Mean CV Score : 0.7922958397534668
# Std deviation : 0.017637669142336193

# %% [markdown]
# ## Decision Tree Classifier

# %%
dtc=DecisionTreeClassifier()
dtc.fit(X_train,Y_train)
y_pred=dtc.predict(X_test)
print('\033[1m'+'Decision Tree Classifier Evaluation'+'\033[0m')
print('\n')
print('\033[1m'+'Accuracy Score of Decision Tree Classifier :'+'\033[0m', accuracy_score(Y_test, y_pred))
print('\n')
print('\033[1m'+'Confusion matrix of Decision Tree Classifier :'+'\033[0m \n',confusion_matrix(Y_test, y_pred))
print('\n')
print('\033[1m'+'classification Report of Decision Tree Classifier'+'\033[0m \n',classification_report(Y_test, y_pred))
# Out:
# Decision Tree Classifier Evaluation
#
#
# Accuracy Score of Decision Tree Classifier : 0.7963800904977375
#
#
# Confusion matrix of Decision Tree Classifier :
#  [[107  22]
#  [ 23  69]]
#
#
# classification Report of Decision Tree Classifier
#                precision    recall  f1-score   support
#
#            0       0.82      0.83      0.83       129
#            1       0.76      0.75      0.75        92
#
#     accuracy                           0.80       221
#    macro avg       0.79      0.79      0.79       221
# weighted avg       0.80      0.80      0.80       221

# %%
from sklearn.model_selection import cross_val_score
CVscore = cross_val_score(dtc, X_scale, Y, cv =5)
print('\033[1m'+'Cross Validation Score', dtc, ':'+'\033[0m\n')
print("CVScore :" ,CVscore)
print("Mean CV Score :",CVscore.mean())
print("Std deviation :",CVscore.std())
# Out:
# Cross Validation Score DecisionTreeClassifier() :
#
# CVScore : [0.74576271 0.78977273 0.8125     0.77272727 0.81818182]
# Mean CV Score : 0.787788906009245
# Std deviation : 0.02657576570778487

# %% [markdown]
# ## Random Forest Classifier

# %%
rfc=RandomForestClassifier()
rfc.fit(X_train,Y_train)
y_pred=rfc.predict(X_test)
print('\033[1m'+'Random Forest Classifier'+'\033[0m')
print('\n')
print('\033[1m'+'Accuracy Score of Random Forest Classifier :'+'\033[0m', accuracy_score(Y_test, y_pred))
print('\n')
print('\033[1m'+'Confusion matrix of Random Forest Classifier :'+'\033[0m \n',confusion_matrix(Y_test, y_pred))
print('\n')
print('\033[1m'+'classification Report of Random Forest Classifier'+'\033[0m \n',classification_report(Y_test, y_pred))
# Out:
# Random Forest Classifier
#
#
# Accuracy Score of Random Forest Classifier : 0.8506787330316742
#
#
# Confusion matrix of Random Forest Classifier :
#  [[113  16]
#  [ 17  75]]
#
#
# classification Report of Random Forest Classifier
#                precision    recall  f1-score   support
#
#            0       0.87      0.88      0.87       129
#            1       0.82      0.82      0.82        92
#
#     accuracy                           0.85       221
#    macro avg       0.85      0.85      0.85       221
# weighted avg       0.85      0.85      0.85       221

# %%
from sklearn.model_selection import cross_val_score
CVscore = cross_val_score(rfc, X_scale, Y, cv =5)
print('\033[1m'+'Cross Validation Score', rfc, ':'+'\033[0m\n')
print("CVScore :" ,CVscore)
print("Mean CV Score :",CVscore.mean())
print("Std deviation :",CVscore.std())
# Out:
# Cross Validation Score RandomForestClassifier() :
#
# CVScore : [0.81355932 0.80113636 0.88068182 0.76704545 0.8125    ]
# Mean CV Score : 0.8149845916795069
# Std deviation : 0.036916837482549716

# %% [markdown]
# ## AdaBoost Classifier

# %%
adbc=AdaBoostClassifier()
adbc.fit(X_train,Y_train)
y_pred=adbc.predict(X_test)
print('\033[1m'+'AdaBoost Classifier Evaluation'+'\033[0m')
print('\n')
print('\033[1m'+'Accuracy Score of AdaBoost Classifier :'+'\033[0m', accuracy_score(Y_test, y_pred))
print('\n')
print('\033[1m'+'Confusion matrix of AdaBoost Classifier :'+'\033[0m \n',confusion_matrix(Y_test, y_pred))
print('\n')
print('\033[1m'+'classification Report of AdaBoost Classifier'+'\033[0m \n',classification_report(Y_test, y_pred))
# Out:
# AdaBoost Classifier Evaluation
#
#
# Accuracy Score of AdaBoost Classifier : 0.8642533936651584
#
#
# Confusion matrix of AdaBoost Classifier :
#  [[117  12]
#  [ 18  74]]
#
#
# classification Report of AdaBoost Classifier
#                precision    recall  f1-score   support
#
#            0       0.87      0.91      0.89       129
#            1       0.86      0.80      0.83        92
#
#     accuracy                           0.86       221
#    macro avg       0.86      0.86      0.86       221
# weighted avg       0.86      0.86      0.86       221

# %%
from sklearn.model_selection import cross_val_score
CVscore = cross_val_score(adbc, X_scale, Y, cv =5)
print('\033[1m'+'Cross Validation Score',adbc, ':'+'\033[0m\n')
print("CVScore :" ,CVscore)
print("Mean CV Score :",CVscore.mean())
print("Std deviation :",CVscore.std())
# Out:
# Cross Validation Score AdaBoostClassifier() :
#
# CVScore : [0.78531073 0.8125     0.81818182 0.80113636 0.85795455]
# Mean CV Score : 0.8150166923472009
# Std deviation : 0.024228571770988406

# %% [markdown]
# ## Gradient Boosting Classifier

# %%
grad_bc=GradientBoostingClassifier()
grad_bc.fit(X_train,Y_train)
y_pred=grad_bc.predict(X_test)
print('\033[1m'+'Gradient Boosting Classifier Evaluation'+'\033[0m')
print('\n')
print('\033[1m'+'Accuracy Score of Gradient Boosting Classifier :'+'\033[0m', accuracy_score(Y_test, y_pred))
print('\n')
print('\033[1m'+'Confusion matrix of Gradient Boosting Classifier :'+'\033[0m \n',confusion_matrix(Y_test, y_pred))
print('\n')
print('\033[1m'+'classification Report of Gradient Boosting Classifier'+'\033[0m \n',classification_report(Y_test, y_pred))
# Out:
# Gradient Boosting Classifier Evaluation
#
#
# Accuracy Score of Gradient Boosting Classifier : 0.832579185520362
#
#
# Confusion matrix of Gradient Boosting Classifier :
#  [[117  12]
#  [ 25  67]]
#
#
# classification Report of Gradient Boosting Classifier
#                precision    recall  f1-score   support
#
#            0       0.82      0.91      0.86       129
#            1       0.85      0.73      0.78        92
#
#     accuracy                           0.83       221
#    macro avg       0.84      0.82      0.82       221
# weighted avg       0.83      0.83      0.83       221

# %%
from sklearn.model_selection import cross_val_score
CVscore = cross_val_score(grad_bc, X_scale, Y, cv =5)
print('\033[1m'+'Cross Validation Score', grad_bc, ':'+'\033[0m\n')
print("CVScore :" ,CVscore)
print("Mean CV Score :",CVscore.mean())
print("Std deviation :",CVscore.std())
# Out:
# Cross Validation Score GradientBoostingClassifier() :
#
# CVScore : [0.83050847 0.8125     0.85227273 0.79545455 0.85795455]
# Mean CV Score : 0.8297380585516179
# Std deviation : 0.023567286230155634

# %% [markdown]
# # Hyper Parameter Tuning : GridSearchCV

# %%
from sklearn.model_selection import GridSearchCV
parameter = [{'fit_intercept': [True, False], #default: True
            'penalty': ['l1','l2'],
            'solver': ['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga'], #default: lbfgs
            'random_state': [69]
             }]

# %%
GCV = GridSearchCV(LogisticRegression(),parameter,verbose=5)
GCV.fit(X_train,Y_train)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [CV 1/5] END fit_intercept=True, penalty=l1, random_state=69, solver=newton-cg;, score=nan total time=   0.0s
# [CV 2/5] END fit_intercept=True, penalty=l1, random_state=69, solver=newton-cg;, score=nan total time=   0.0s
# [CV 3/5] END fit_intercept=True, penalty=l1, random_state=69, solver=newton-cg;, score=nan total time=   0.0s
# [CV 4/5] END fit_intercept=True, penalty=l1, random_state=69, solver=newton-cg;, score=nan total time=   0.0s
# [CV 5/5] END fit_intercept=True, penalty=l1, random_state=69, solver=newton-cg;, score=nan total time=   0.0s
# [CV 1/5] END fit_intercept=True, penalty=l1, random_state=69, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/5] END fit_intercept=True, penalty=l1, random_state=69, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/5] END fit_intercept=True, penalty=l1, random_state=69, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/5] END fit_intercept=True, penalty=l1, random_state=69, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END fit_intercept=True, penalty=l1, random_state=69, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/5] END fit_intercept=True, penalty=l1, random_state=69, solver=liblinear;, score=0.826 total time=   0.0s
# [CV 2/5] END fit_intercept=True, penalty=l1, random_state=69, solver=liblinear;, score=0.773 total time=   0.0s
# [CV 3/5] END fit_intercept=True, penalty=l1, random_state=69, solver=liblinear;, score=0.765 total time=   0.0s
# [CV 4/5] END fit_intercept=True, penalty=l1, random_state=69, solver=liblinear;, score=0.705 total time=   0.0s
# [CV 5/5] END fit_intercept=True, penalty=l1, random_state=69, solver=liblinear;, score=0.742 total time=   0.0s
# [CV 1/5] END fit_intercept=True, penalty=l1, random_state=69, solver=sag;, score=nan total time=   0.0s
# [CV 2/5] END fit_intercept=True, penalty=l1, random_state=69, solver=sag;, score=nan total time=   0.0s
# [CV 3/5] END fit_intercept=True, penalty=l1, random_state=69, solver=sag;, score=nan total time=   0.0s
# [CV 4/5] END fit_intercept=True, penalty=l1, random_state=69, solver=sag;, score=nan total time=   0.0s
# [CV 5/5] END fit_intercept=True, penalty=l1, random_state=69, solver=sag;, score=nan total time=   0.0s
# [CV 1/5] END fit_intercept=True, penalty=l1, random_state=69, solver=saga;, score=0.818 total time=   0.0s
# [CV 2/5] END fit_intercept=True, penalty=l1, random_state=69, solver=saga;, score=0.773 total time=   0.0s
# [CV 3/5] END fit_intercept=True, penalty=l1, random_state=69, solver=saga;, score=0.765 total time=   0.0s
# [CV 4/5] END fit_intercept=True, penalty=l1, random_state=69, solver=saga;, score=0.705 total time=   0.0s
# [CV 5/5] END fit_intercept=True, penalty=l1, random_state=69, solver=saga;, score=0.742 total time=   0.0s
# [CV 1/5] END fit_intercept=True, penalty=l2, random_state=69, solver=newton-cg;, score=0.826 total time=   0.0s
# [CV 2/5] END fit_intercept=True, penalty=l2, random_state=69, solver=newton-cg;, score=0.773 total time=   0.0s
# [CV 3/5] END fit_intercept=True, penalty=l2, random_state=69, solver=newton-cg;, score=0.765 total time=   0.0s
# [CV 4/5] END fit_intercept=True, penalty=l2, random_state=69, solver=newton-cg;, score=0.712 total time=   0.0s
# [CV 5/5] END fit_intercept=True, penalty=l2, random_state=69, solver=newton-cg;, score=0.742 total time=   0.0s
# [CV 1/5] END fit_intercept=True, penalty=l2, random_state=69, solver=lbfgs;, score=0.826 total time=   0.0s
# [CV 2/5] END fit_intercept=True, penalty=l2, random_state=69, solver=lbfgs;, score=0.773 total time=   0.0s
# [CV 3/5] END fit_intercept=True, penalty=l2, random_state=69, solver=lbfgs;, score=0.765 total time=   0.0s
# [CV 4/5] END fit_intercept=True, penalty=l2, random_state=69, solver=lbfgs;, score=0.712 total time=   0.0s
# [CV 5/5] END fit_intercept=True, penalty=l2, random_state=69, solver=lbfgs;, score=0.742 total time=   0.0s
# [CV 1/5] END fit_intercept=True, penalty=l2, random_state=69, solver=liblinear;, score=0.826 total time=   0.0s
# [CV 2/5] END fit_intercept=True, penalty=l2, random_state=69, solver=liblinear;, score=0.773 total time=   0.0s
# [CV 3/5] END fit_intercept=True, penalty=l2, random_state=69, solver=liblinear;, score=0.765 total time=   0.0s
# [CV 4/5] END fit_intercept=True, penalty=l2, random_state=69, solver=liblinear;, score=0.705 total time=   0.0s
# [CV 5/5] END fit_intercept=True, penalty=l2, random_state=69, solver=liblinear;, score=0.742 total time=   0.0s
# [CV 1/5] END fit_intercept=True, penalty=l2, random_state=69, solver=sag;, score=0.826 total time=   0.0s
# [CV 2/5] END fit_intercept=True, penalty=l2, random_state=69, solver=sag;, score=0.773 total time=   0.0s
# [CV 3/5] END fit_intercept=True, penalty=l2, random_state=69, solver=sag;, score=0.765 total time=   0.0s
# [CV 4/5] END fit_intercept=True, penalty=l2, random_state=69, solver=sag;, score=0.712 total time=   0.0s
# [CV 5/5] END fit_intercept=True, penalty=l2, random_state=69, solver=sag;, score=0.742 total time=   0.0s
# [CV 1/5] END fit_intercept=True, penalty=l2, random_state=69, solver=saga;, score=0.826 total time=   0.0s
# [CV 2/5] END fit_intercept=True, penalty=l2, random_state=69, solver=saga;, score=0.773 total time=   0.0s
# [CV 3/5] END fit_intercept=True, penalty=l2, random_state=69, solver=saga;, score=0.765 total time=   0.0s
# [CV 4/5] END fit_intercept=True, penalty=l2, random_state=69, solver=saga;, score=0.712 total time=   0.0s
# [CV 5/5] END fit_intercept=True, penalty=l2, random_state=69, solver=saga;, score=0.742 total time=   0.0s
# [CV 1/5] END fit_intercept=False, penalty=l1, random_state=69, solver=newton-cg;, score=nan total time=   0.0s
# [CV 2/5] END fit_intercept=False, penalty=l1, random_state=69, solver=newton-cg;, score=nan total time=   0.0s
# [CV 3/5] END fit_intercept=False, penalty=l1, random_state=69, solver=newton-cg;, score=nan total time=   0.0s
# [CV 4/5] END fit_intercept=False, penalty=l1, random_state=69, solver=newton-cg;, score=nan total time=   0.0s
# [CV 5/5] END fit_intercept=False, penalty=l1, random_state=69, solver=newton-cg;, score=nan total time=   0.0s
# [CV 1/5] END fit_intercept=False, penalty=l1, random_state=69, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/5] END fit_intercept=False, penalty=l1, random_state=69, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/5] END fit_intercept=False, penalty=l1, random_state=69, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/5] END fit_intercept=False, penalty=l1, random_state=69, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END fit_intercept=False, penalty=l1, random_state=69, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/5] END fit_intercept=False, penalty=l1, random_state=69, solver=liblinear;, score=0.841 total time=   0.0s
# [CV 2/5] END fit_intercept=False, penalty=l1, random_state=69, solver=liblinear;, score=0.765 total time=   0.0s
# [CV 3/5] END fit_intercept=False, penalty=l1, random_state=69, solver=liblinear;, score=0.765 total time=   0.0s
# [CV 4/5] END fit_intercept=False, penalty=l1, random_state=69, solver=liblinear;, score=0.689 total time=   0.0s
# [CV 5/5] END fit_intercept=False, penalty=l1, random_state=69, solver=liblinear;, score=0.720 total time=   0.0s
# [CV 1/5] END fit_intercept=False, penalty=l1, random_state=69, solver=sag;, score=nan total time=   0.0s
# [CV 2/5] END fit_intercept=False, penalty=l1, random_state=69, solver=sag;, score=nan total time=   0.0s
# [CV 3/5] END fit_intercept=False, penalty=l1, random_state=69, solver=sag;, score=nan total time=   0.0s
# [CV 4/5] END fit_intercept=False, penalty=l1, random_state=69, solver=sag;, score=nan total time=   0.0s
# [CV 5/5] END fit_intercept=False, penalty=l1, random_state=69, solver=sag;, score=nan total time=   0.0s
# [CV 1/5] END fit_intercept=False, penalty=l1, random_state=69, solver=saga;, score=0.841 total time=   0.0s
# [CV 2/5] END fit_intercept=False, penalty=l1, random_state=69, solver=saga;, score=0.765 total time=   0.0s
# [CV 3/5] END fit_intercept=False, penalty=l1, random_state=69, solver=saga;, score=0.765 total time=   0.0s
# [CV 4/5] END fit_intercept=False, penalty=l1, random_state=69, solver=saga;, score=0.689 total time=   0.0s
# [CV 5/5] END fit_intercept=False, penalty=l1, random_state=69, solver=saga;, score=0.727 total time=   0.0s
# [CV 1/5] END fit_intercept=False, penalty=l2, random_state=69, solver=newton-cg;, score=0.841 total time=   0.0s
# [CV 2/5] END fit_intercept=False, penalty=l2, random_state=69, solver=newton-cg;, score=0.765 total time=   0.0s
# [CV 3/5] END fit_intercept=False, penalty=l2, random_state=69, solver=newton-cg;, score=0.773 total time=   0.0s
# [CV 4/5] END fit_intercept=False, penalty=l2, random_state=69, solver=newton-cg;, score=0.689 total time=   0.0s
# [CV 5/5] END fit_intercept=False, penalty=l2, random_state=69, solver=newton-cg;, score=0.727 total time=   0.0s
# [CV 1/5] END fit_intercept=False, penalty=l2, random_state=69, solver=lbfgs;, score=0.841 total time=   0.0s
# [CV 2/5] END fit_intercept=False, penalty=l2, random_state=69, solver=lbfgs;, score=0.765 total time=   0.0s
# [CV 3/5] END fit_intercept=False, penalty=l2, random_state=69, solver=lbfgs;, score=0.773 total time=   0.0s
# [CV 4/5] END fit_intercept=False, penalty=l2, random_state=69, solver=lbfgs;, score=0.689 total time=   0.0s
# [CV 5/5] END fit_intercept=False, penalty=l2, random_state=69, solver=lbfgs;, score=0.727 total time=   0.0s
# [CV 1/5] END fit_intercept=False, penalty=l2, random_state=69, solver=liblinear;, score=0.841 total time=   0.0s
# [CV 2/5] END fit_intercept=False, penalty=l2, random_state=69, solver=liblinear;, score=0.765 total time=   0.0s
# [CV 3/5] END fit_intercept=False, penalty=l2, random_state=69, solver=liblinear;, score=0.773 total time=   0.0s
# [CV 4/5] END fit_intercept=False, penalty=l2, random_state=69, solver=liblinear;, score=0.689 total time=   0.0s
# [CV 5/5] END fit_intercept=False, penalty=l2, random_state=69, solver=liblinear;, score=0.727 total time=   0.0s
# [CV 1/5] END fit_intercept=False, penalty=l2, random_state=69, solver=sag;, score=0.841 total time=   0.0s
# [CV 2/5] END fit_intercept=False, penalty=l2, random_state=69, solver=sag;, score=0.765 total time=   0.0s
# [CV 3/5] END fit_intercept=False, penalty=l2, random_state=69, solver=sag;, score=0.773 total time=   0.0s
# [CV 4/5] END fit_intercept=False, penalty=l2, random_state=69, solver=sag;, score=0.689 total time=   0.0s
# [CV 5/5] END fit_intercept=False, penalty=l2, random_state=69, solver=sag;, score=0.727 total time=   0.0s
# [CV 1/5] END fit_intercept=False, penalty=l2, random_state=69, solver=saga;, score=0.841 total time=   0.0s
# [CV 2/5] END fit_intercept=False, penalty=l2, random_state=69, solver=saga;, score=0.765 total time=   0.0s
# [CV 3/5] END fit_intercept=False, penalty=l2, random_state=69, solver=saga;, score=0.773 total time=   0.0s
# [CV 4/5] END fit_intercept=False, penalty=l2, random_state=69, solver=saga;, score=0.689 total time=   0.0s
# [CV 5/5] END fit_intercept=False, penalty=l2, random_state=69, solver=saga;, score=0.727 total time=   0.0s
# C:\Users\GauRav SingH\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 30 fits failed out of a total of 100.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 10 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\GauRav SingH\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\GauRav SingH\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py", line 1461, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "C:\Users\GauRav SingH\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py", line 447, in _check_solver
#     raise ValueError(
# ValueError: Solver newton-cg supports only 'l2' or 'none' penalties, got l1 penalty.
#
# --------------------------------------------------------------------------------
# 10 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\GauRav SingH\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\GauRav SingH\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py", line 1461, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "C:\Users\GauRav SingH\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py", line 447, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
# --------------------------------------------------------------------------------
# 10 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\GauRav SingH\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\GauRav SingH\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py", line 1461, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "C:\Users\GauRav SingH\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py", line 447, in _check_solver
#     raise ValueError(
# ValueError: Solver sag supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\GauRav SingH\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_search.py:969: UserWarning: One or more of the test scores are non-finite: [       nan        nan 0.76212121        nan 0.76060606 0.76363636
#  0.76363636 0.76212121 0.76363636 0.76363636        nan        nan
#  0.75606061        nan 0.75757576 0.75909091 0.75909091 0.75909091
#  0.75909091 0.75909091]
#   warnings.warn(
# GridSearchCV(estimator=LogisticRegression(),
#              param_grid=[{'fit_intercept': [True, False],
#                           'penalty': ['l1', 'l2'], 'random_state': [69],
#                           'solver': ['newton-cg', 'lbfgs', 'liblinear', 'sag',
#                                      'saga']}],
#              verbose=5)

# %%
GCV.best_params_
# Out:
# {'fit_intercept': True,
#  'penalty': 'l2',
#  'random_state': 69,
#  'solver': 'newton-cg'}

# %% [markdown]
# ## Final Model

# %%
Final_mod = LogisticRegression(fit_intercept =True,penalty= "l2",solver='newton-cg',random_state= 69)
Final_mod.fit(X_train,Y_train)
y_pred=Final_mod.predict(X_test)
print('\033[1m'+'Final Random Forest Classifier Model'+'\033[0m')
print('\033[1m'+'Accuracy Score :'+'\033[0m\n', accuracy_score(Y_test, y_pred))
print('\n')
print('\033[1m'+'Confusion matrix of Random Forest Classifier :'+'\033[0m \n',confusion_matrix(Y_test, y_pred))
print('\n')
print('\033[1m'+'Classification Report of Random Forest Classifier'+'\033[0m \n',classification_report(Y_test, y_pred))
# Out:
# Final Random Forest Classifier Model
# Accuracy Score :
#  0.8687782805429864
#
#
# Confusion matrix of Random Forest Classifier :
#  [[120   9]
#  [ 20  72]]
#
#
# Classification Report of Random Forest Classifier
#                precision    recall  f1-score   support
#
#            0       0.86      0.93      0.89       129
#            1       0.89      0.78      0.83        92
#
#     accuracy                           0.87       221
#    macro avg       0.87      0.86      0.86       221
# weighted avg       0.87      0.87      0.87       221

# %%
# Lets plot confusion matrix for  FinalModel
Matrix = confusion_matrix(Y_test, y_pred)

x_labels = ["NO","YES"]
y_labels = ["NO","YES"]

fig , ax = plt.subplots(figsize=(5,5))
sns.heatmap(Matrix, annot = True,linewidths=.2, linecolor="black", fmt = ".0f", ax=ax, 
            cmap="plasma", xticklabels = x_labels, yticklabels = y_labels)

plt.xlabel("Predicted Label",fontsize=14,fontweight='bold')
plt.ylabel("True Label",fontsize=14,fontweight='bold')
plt.title('Confusion Matrix for Final Model',fontsize=20,fontweight='bold')
plt.show()

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
from sklearn.metrics import plot_roc_curve
disp = plot_roc_curve(Final_mod,X_test,Y_test)   
plt.legend(prop={'size':11}, loc='lower right')
plt.title('AOC ROC Curve of Final Model',fontsize=20,fontweight='bold')
plt.show()
auc_score = roc_auc_score(Y_test, Final_mod.predict(X_test))
print('\033[1m'+'Auc Score :'+'\033[0m\n',auc_score)
# Out:
# C:\Users\GauRav SingH\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_roc_curve is deprecated; Function :func:`plot_roc_curve` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: :meth:`sklearn.metric.RocCurveDisplay.from_predictions` or :meth:`sklearn.metric.RocCurveDisplay.from_estimator`.
#   warnings.warn(msg, category=FutureWarning)
# Auc Score :
#  0.8564206268958544

# %% [markdown]
# ## Saving model

# %%
import joblib
joblib.dump(Final_mod,'Titanic_Survival_Project.pkl')
# Out:
# ['Titanic_Survival_Project.pkl']

# %% [markdown]
# ## Predicting the Final Model

# %%
# Prediction
prediction = Final_mod.predict(X_test)

# %%
Actual = np.array(Y_test)
df_Pred = pd.DataFrame()
df_Pred["Predicted Values"] = prediction
df_Pred["Actual Values"] = Actual
df_Pred.head()
# Out:
#    Predicted Values  Actual Values
# 0                 1              1
# 1                 0              0
# 2                 1              1
# 3                 1              1
# 4                 0              0
